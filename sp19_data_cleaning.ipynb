# %% [markdown]
# <a href="https://colab.research.google.com/github/khushimalik3122/salary-predictor-19/blob/main/sp19_data_cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Machine Learning Project
# Data Analyst Job Market: Machine Learning Project
# By: Khushi Malik
# Tools: Machine Learning, Python, SQL, Excel
# Domain: Financial Analytics
# Difficulty Level: Intermediate

# %% [markdown]
# # Introduction
# In the wake of the pandemic, the global job market shifted dramatically—millions were left jobless, and uncertainty loomed large. This project dives deep into a dataset of over 2000 data analyst job listings, created by picklesueat, with a mission to help streamline job searches and unlock hiring trends.

# %% [markdown]
# # Problem statement
# "Given a dataset of Data Analyst job postings, how can we identify key trends in hiring, predict salary expectations based on job and company features, and offer strategic insights into employer attractiveness and location-based demand?”
#
# This breaks into three core questions:
#
#  Which job roles, locations, and companies dominate the hiring space?
#
# How do company rating and job location impact average salaries?
#
# Can we predict the salary range of a Data Analyst job based on its attributes?

# %% [markdown]
# # Objectives
# Analyze hiring trends by location, company, job title, salary, and rating
#
# Build a machine learning model to predict salary ranges
#
# Provide strategic insights into:
#
# Company branding and reputation
#
# Salary competitiveness
#
# Location-based demand

# %% [markdown]
# # Impact
# For Employers:
#
# Refine salary benchmarking
#
# Enhance employer branding
#
# Optimize job postings for better reach
#
# For Job Seekers:
#
# Understand the market better
#
# Gain confidence in salary negotiations
#
# Apply strategically to companies and locations that align with goals

# %% [markdown]
# # Methodology: Step-by-Step Approach
# 1. Data Collection Source:
# this  dataset is alredy given to me for internship.
#
# 2. Data Understanding
# Perform an initial scan of the dataset: dimensions, column names, data types.
#
# Identify target variable (e.g., Salary Estimate) and relevant features (e.g., Location, Company Rating, Industry, etc.).
#
# 3. Data Cleaning
# Handle missing values and nulls
#
# Standardize salary fields (remove special characters, convert ranges to averages)
#
# Remove or unify inconsistent categorical values (e.g., “New York, NY” vs “NYC”)
#
# Extract skills or keywords from Job Description using NLP if needed
#
# 4. Exploratory Data Analysis (EDA)
# Visualize trends:
#
# Top hiring locations
#
# Most active companies
#
# Salary distribution across roles/locations
#
# Correlation between ratings and salaries
#
# Use plots: histograms, bar charts, box plots, heatmaps
#
# 5. Feature Engineering
# Extract features:
#
# Experience Level from Job Description
#
# Industry Type or Revenue Bucket
#
# Create dummy variables for categorical data (one-hot encoding)
#
# Normalize numerical features if needed
#
# 6. Model Building
# Objective: Predict salary range or average salary
#
# Use ML models:
#
# Linear Regression
#
# Random Forest Regressor
#
# XGBoost (optional for advanced accuracy)
#
# Split into train/test sets, evaluate using MAE, RMSE, R² Score
#
# 7. Insights & Recommendations
# Top industries and companies offering high salaries
#
# Skills most in demand
#
# Locations with the highest-paying roles
#
# Tips for job seekers based on the data
#
# 8. Conclusion & Impact
# Wrap up the findings
#
# Describe practical applications for:
#
# Job seekers
#
# Employers
#
# Career counselors

# %% [markdown]
# # data cleaning

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

#  dataset Loading
file_path = "/content/drive/MyDrive/sp_19_app/job_data_data_analyst.csv"
df = pd.read_csv(file_path)

# Displaying of  basic info
df_info = df.info()
df_head = df.head()
df_nulls = df.isnull().sum()

df_info, df_head, df_nulls
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2253 entries, 0 to 2252
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         2253 non-null   int64
#  1   Job Title          2253 non-null   object
#  2   Salary Estimate    2253 non-null   object
#  3   Job Description    2253 non-null   object
#  4   Rating             2253 non-null   float64
#  5   Company Name       2252 non-null   object
#  6   Location           2253 non-null   object
#  7   Headquarters       2253 non-null   object
#  8   Size               2253 non-null   object
#  9   Founded            2253 non-null   int64
#  10  Type of ownership  2253 non-null   object
#  11  Industry           2253 non-null   object
#  12  Sector             2253 non-null   object
#  13  Revenue            2253 non-null   object
#  14  Competitors        2253 non-null   object
#  15  Easy Apply         2253 non-null   object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 281.8+ KB
# (None,
#     Unnamed: 0                                          Job Title  \
#  0           0  Data Analyst, Center on Immigration and Justic...
#  1           1                               Quality Data Analyst
#  2           2  Senior Data Analyst, Insights & Analytics Team...
#  3           3                                       Data Analyst
#  4           4                             Reporting Data Analyst
#
#                Salary Estimate  \
#  0  $37K-$66K (Glassdoor est.)
#  1  $37K-$66K (Glassdoor est.)
#  2  $37K-$66K (Glassdoor est.)
#  3  $37K-$66K (Glassdoor est.)
#  4  $37K-$66K (Glassdoor est.)
#
#                                       Job Description  Rating  \
#  0  Are you eager to roll up your sleeves and harn...     3.2
#  1  Overview\n\nProvides analytical and technical ...     3.8
#  2  We’re looking for a Senior Data Analyst who ha...     3.4
#  3  Requisition NumberRR-0001939\nRemote:Yes\nWe c...     4.1
#  4  ABOUT FANDUEL GROUP\n\nFanDuel Group is a worl...     3.9
#
#                                Company Name      Location  Headquarters  \
#  0           Vera Institute of Justice\n3.2  New York, NY  New York, NY
#  1  Visiting Nurse Service of New York\n3.8  New York, NY  New York, NY
#  2                         Squarespace\n3.4  New York, NY  New York, NY
#  3                            Celerity\n4.1  New York, NY    McLean, VA
#  4                             FanDuel\n3.9  New York, NY  New York, NY
#
#                       Size  Founded               Type of ownership  \
#  0    201 to 500 employees     1961          Nonprofit Organization
#  1        10000+ employees     1893          Nonprofit Organization
#  2  1001 to 5000 employees     2003               Company - Private
#  3    201 to 500 employees     2002  Subsidiary or Business Segment
#  4   501 to 1000 employees     2009               Company - Private
#
#                             Industry                            Sector  \
#  0                 Social Assistance                        Non-Profit
#  1  Health Care Services & Hospitals                       Health Care
#  2                          Internet            Information Technology
#  3                       IT Services            Information Technology
#  4               Sports & Recreation  Arts, Entertainment & Recreation
#
#                        Revenue Competitors Easy Apply
#  0  $100 to $500 million (USD)          -1       True
#  1      $2 to $5 billion (USD)          -1         -1
#  2    Unknown / Non-Applicable     GoDaddy         -1
#  3   $50 to $100 million (USD)          -1         -1
#  4  $100 to $500 million (USD)  DraftKings       True  ,
#  Unnamed: 0           0
#  Job Title            0
#  Salary Estimate      0
#  Job Description      0
#  Rating               0
#  Company Name         1
#  Location             0
#  Headquarters         0
#  Size                 0
#  Founded              0
#  Type of ownership    0
#  Industry             0
#  Sector               0
#  Revenue              0
#  Competitors          0
#  Easy Apply           0
#  dtype: int64)

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'Easy Apply'],
#       dtype='object')

# %%
# 1. Droping of  'Unnamed: 0' column
df.drop(columns=['Unnamed: 0','Competitors','Founded'], inplace=True)

# 2. Cleaning 'Company Name' - removing of  trailing rating (e.g., '\n3.2')
df['Company Name'] = df['Company Name'].str.replace(r'\n\d\.\d$', '', regex=True)

# 3. Cleaning of  'Salary Estimate'
# Removing of  '(Glassdoor est.)', '$', 'K', 'per hour', etc.
df['Salary Estimate Cleaned'] = df['Salary Estimate'].str.replace(r'\(.*\)', '', regex=True)
df['Salary Estimate Cleaned'] = df['Salary Estimate Cleaned'].str.replace('$', '', regex=False)
df['Salary Estimate Cleaned'] = df['Salary Estimate Cleaned'].str.replace('K', '', regex=False)
df['Salary Estimate Cleaned'] = df['Salary Estimate Cleaned'].str.replace(' ', '', regex=False)
df['Salary Estimate Cleaned'] = df['Salary Estimate Cleaned'].str.replace('PerHour', '', regex=False)
df['Salary Estimate Cleaned'] = df['Salary Estimate Cleaned'].str.replace('perhour', '', regex=False)
df['Salary Estimate Cleaned'] = df['Salary Estimate Cleaned'].str.replace('EmployerProvidedSalary:', '', regex=False)

# Converting of  range to min, max, avg salary
def extract_salary_range(sal):
    try:
        parts = sal.split('-')
        if len(parts) == 2:
            min_sal = int(parts[0])
            max_sal = int(parts[1])
            avg_sal = (min_sal + max_sal) // 2
            return pd.Series([min_sal, max_sal, avg_sal])
    except:
        return pd.Series([None, None, None])

df[['Min Salary (K)', 'Max Salary (K)', 'Avg Salary (K)']] = df['Salary Estimate Cleaned'].apply(extract_salary_range)

# 4. Replacing of  '-1' with None in applicable columns
columns_to_clean = ['Easy Apply']
for col in columns_to_clean:
    df[col] = df[col].replace('-1', None)

# 5. Handling of  missing 'Company Name' value by filling it with 'Unknown'
df['Company Name'].fillna('Unknown', inplace=True)

# Displaying of  cleaned sample
df.head(3)
# Out:
# <ipython-input-5-6028c41ca2bc>:37: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Company Name'].fillna('Unknown', inplace=True)
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
#
#                          Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York  New York, NY  New York, NY
# 2                         Squarespace  New York, NY  New York, NY
#
#                      Size       Type of ownership  \
# 0    201 to 500 employees  Nonprofit Organization
# 1        10000+ employees  Nonprofit Organization
# 2  1001 to 5000 employees       Company - Private
#
#                            Industry                  Sector  \
# 0                 Social Assistance              Non-Profit
# 1  Health Care Services & Hospitals             Health Care
# 2                          Internet  Information Technology
#
#                       Revenue Easy Apply Salary Estimate Cleaned  \
# 0  $100 to $500 million (USD)       True                   37-66
# 1      $2 to $5 billion (USD)       None                   37-66
# 2    Unknown / Non-Applicable       None                   37-66
#
#    Min Salary (K)  Max Salary (K)  Avg Salary (K)
# 0            37.0            66.0            51.0
# 1            37.0            66.0            51.0
# 2            37.0            66.0            51.0

# %%
import numpy as np

# 1. Split 'Location' and 'Headquarters' into City and State
if 'Location' in df.columns:
    df[['Job City', 'Job State']] = df['Location'].str.split(pat=',', n=1, expand=True)
else:
    print("Column 'Location' not found in the DataFrame.")

if 'Headquarters' in df.columns:
    df[['HQ City', 'HQ State']] = df['Headquarters'].str.split(pat=',', n=1, expand=True)
else:
    print("Column 'Headquarters' not found in the DataFrame.")
# Strip whitespace
df['Job City'] = df['Job City'].str.strip()
df['Job State'] = df['Job State'].str.strip()
df['HQ City'] = df['HQ City'].str.strip()
df['HQ State'] = df['HQ State'].str.strip()

# 2. Clean 'Job Description' and extract skill mentions
skills = ['Python', 'Excel', 'SQL', 'R', 'Tableau', 'Power BI', 'Machine Learning']
for skill in skills:
    df[f'Skill_{skill}'] = df['Job Description'].str.contains(skill, case=False, na=False)

# 3. Clean categorical fields
categorical_columns = ['Size', 'Revenue', 'Type of ownership', 'Industry', 'Sector']
for col in categorical_columns:
    df[col] = df[col].replace('-1', np.nan).str.strip()

# 4. Convert 'Rating' to float
df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')

# Preview the cleaned dataset
df.head(3)
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
#
#               Salary Estimate  \
# 0  $37K-$66K (Glassdoor est.)
# 1  $37K-$66K (Glassdoor est.)
# 2  $37K-$66K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Are you eager to roll up your sleeves and harn...     3.2
# 1  Overview\n\nProvides analytical and technical ...     3.8
# 2  We’re looking for a Senior Data Analyst who ha...     3.4
#
#                          Company Name      Location  Headquarters  \
# 0           Vera Institute of Justice  New York, NY  New York, NY
# 1  Visiting Nurse Service of New York  New York, NY  New York, NY
# 2                         Squarespace  New York, NY  New York, NY
#
#                      Size       Type of ownership  \
# 0    201 to 500 employees  Nonprofit Organization
# 1        10000+ employees  Nonprofit Organization
# 2  1001 to 5000 employees       Company - Private
#
#                            Industry  ... Job State   HQ City HQ State  \
# 0                 Social Assistance  ...        NY  New York       NY
# 1  Health Care Services & Hospitals  ...        NY  New York       NY
# 2                          Internet  ...        NY  New York       NY
#
#   Skill_Python  Skill_Excel  Skill_SQL  Skill_R Skill_Tableau Skill_Power BI  \
# 0         True        False       True     True         False          False
# 1        False         True       True     True         False          False
# 2         True         True       True     True          True          False
#
#   Skill_Machine Learning
# 0                  False
# 1                  False
# 2                  False
#
# [3 rows x 28 columns]

# %% [markdown]
# # data processing

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split

#  Striping of  whitespace from column names
df.columns = df.columns.str.strip()

# --- Labeling of Encode 'Company Name' ---
if 'Company Name' in df.columns:
    company_encoder = LabelEncoder()
    df['Company_Encoded'] = company_encoder.fit_transform(df['Company Name'].fillna('Unknown'))

# --- One-hot encoding for selected categorical features ---
categorical_columns = ['Size', 'Revenue', 'Type of ownership', 'Industry', 'Sector']
available_categoricals = [col for col in categorical_columns if col in df.columns]
df = pd.get_dummies(df, columns=available_categoricals, drop_first=True)

# --- Simplifying of  Job Title ---
def simplify_job_title(title):
    title = str(title).lower()
    if 'senior' in title or 'sr' in title:
        return 'Senior Analyst'
    elif 'manager' in title:
        return 'Manager'
    elif 'intern' in title:
        return 'Intern'
    elif 'lead' in title:
        return 'Lead Analyst'
    elif 'data scientist' in title:
        return 'Data Scientist'
    elif 'engineer' in title:
        return 'Engineer'
    else:
        return 'Analyst'

if 'Job Title' in df.columns:
    df['Job Title Simplified'] = df['Job Title'].apply(simplify_job_title)
    df = pd.get_dummies(df, columns=['Job Title Simplified'], drop_first=True)

# --- 'Rating' ---
if 'Rating' in df.columns:
    df['Rating'] = pd.to_numeric(df['Rating'], errors='coerce')
    rating_imputer = SimpleImputer(strategy='mean')
    df['Rating'] = rating_imputer.fit_transform(df[['Rating']]).ravel()
    df['Rating'] = df['Rating'].abs()

# ---  'Easy Apply' ---
if 'Easy Apply' in df.columns:
    df['Easy Apply'] = df['Easy Apply'].map({'Yes': 1, 'No': 0}).fillna(0)

# --- Droping of  Irrelevant Columns ---
to_drop = [ 'Job Description', 'Location', 'Headquarters']
df.drop(columns=[col for col in to_drop if col in df.columns], inplace=True)

# --- Imputing of  remaining missing values ---
imputer = SimpleImputer(strategy='most_frequent')
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)
df=df.dropna(subset=['Salary Estimate Cleaned'])

# %%
df=df.drop(columns=['Salary Estimate'])

# %%
df.head(3)
# Out:
#                                            Job Title  Rating  \
# 0  Data Analyst, Center on Immigration and Justic...     3.2
# 1                               Quality Data Analyst     3.8
# 2  Senior Data Analyst, Insights & Analytics Team...     3.4
#
#                          Company Name  Easy Apply Salary Estimate Cleaned  \
# 0           Vera Institute of Justice         0.0                   37-66
# 1  Visiting Nurse Service of New York         0.0                   37-66
# 2                         Squarespace         0.0                   37-66
#
#    Min Salary (K)  Max Salary (K)  Avg Salary (K)  Job City Job State  ...  \
# 0            37.0            66.0            51.0  New York        NY  ...
# 1            37.0            66.0            51.0  New York        NY  ...
# 2            37.0            66.0            51.0  New York        NY  ...
#
#   Sector_Retail Sector_Telecommunications  Sector_Transportation & Logistics  \
# 0         False                     False                              False
# 1         False                     False                              False
# 2         False                     False                              False
#
#    Sector_Travel & Tourism  Job Title Simplified_Data Scientist  \
# 0                    False                                False
# 1                    False                                False
# 2                    False                                False
#
#    Job Title Simplified_Engineer  Job Title Simplified_Intern  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
#
#    Job Title Simplified_Lead Analyst  Job Title Simplified_Manager  \
# 0                              False                         False
# 1                              False                         False
# 2                              False                         False
#
#    Job Title Simplified_Senior Analyst
# 0                                False
# 1                                False
# 2                                 True
#
# [3 rows x 168 columns]

# %%
df=df.dropna(subset=['Company Name'])

# %%
import numpy as np


# Clean salary columns
salary_encoded_cols = [col for col in df.columns if 'Salary' in col and '_' in col and not col.startswith('Salary Estimate')]
df.drop(columns=salary_encoded_cols, inplace=True)

# Convert salary to numeric
df['Min Salary (K)'] = pd.to_numeric(df['Min Salary (K)'], errors='coerce')
df['Max Salary (K)'] = pd.to_numeric(df['Max Salary (K)'], errors='coerce')

# New Features
df['Salary Range (K)'] = df['Max Salary (K)'] - df['Min Salary (K)']
df['Average Salary (K)'] = (df['Min Salary (K)'] + df['Max Salary (K)']) / 2
df['Log Avg Salary'] = df['Average Salary (K)'].apply(lambda x: np.log(x) if pd.notna(x) and x > 0 else np.nan)

df.head(3)
# Out:
#                                            Job Title  Rating  \
# 0  Data Analyst, Center on Immigration and Justic...     3.2
# 1                               Quality Data Analyst     3.8
# 2  Senior Data Analyst, Insights & Analytics Team...     3.4
#
#                          Company Name  Easy Apply Salary Estimate Cleaned  \
# 0           Vera Institute of Justice         0.0                   37-66
# 1  Visiting Nurse Service of New York         0.0                   37-66
# 2                         Squarespace         0.0                   37-66
#
#    Min Salary (K)  Max Salary (K)  Avg Salary (K)  Job City Job State  ...  \
# 0            37.0            66.0            51.0  New York        NY  ...
# 1            37.0            66.0            51.0  New York        NY  ...
# 2            37.0            66.0            51.0  New York        NY  ...
#
#   Sector_Travel & Tourism Job Title Simplified_Data Scientist  \
# 0                   False                               False
# 1                   False                               False
# 2                   False                               False
#
#    Job Title Simplified_Engineer  Job Title Simplified_Intern  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
#
#    Job Title Simplified_Lead Analyst  Job Title Simplified_Manager  \
# 0                              False                         False
# 1                              False                         False
# 2                              False                         False
#
#    Job Title Simplified_Senior Analyst  Salary Range (K)  Average Salary (K)  \
# 0                                False              29.0                51.5
# 1                                False              29.0                51.5
# 2                                 True              29.0                51.5
#
#    Log Avg Salary
# 0        3.941582
# 1        3.941582
# 2        3.941582
#
# [3 rows x 171 columns]

# %%
def group_job_title(title):
    title = title.lower()
    if 'senior' in title or 'sr.' in title or 'sr ' in title:
        return 'Senior Data Analyst'
    elif 'junior' in title:
        return 'Junior Data Analyst'
    elif 'lead' in title:
        return 'Lead Analyst'
    elif 'business' in title:
        return 'Business Analyst'
    elif 'quality' in title:
        return 'Data Quality Analyst'
    elif 'governance' in title:
        return 'Governance Analyst'
    elif 'reporting' in title:
        return 'Reporting Analyst'
    elif 'marketing' in title:
        return 'Marketing Analyst'
    elif 'science' in title:
        return 'Data Scientist'
    elif 'financial' in title:
        return 'Financial Analyst'
    elif 'healthcare' in title or 'clinical' in title:
        return 'Healthcare Analyst'
    elif 'research' in title:
        return 'Research Analyst'
    elif 'technical' in title or 'warehouse' in title:
        return 'Technical Analyst'
    elif 'product' in title or 'operations' in title:
        return 'Operations/Product Analyst'
    elif 'ii' in title or 'iii' in title or 'i' in title:
        return 'Mid-level Data Analyst'
    elif 'sql' in title:
        return 'Data Analyst'
    elif 'data analyst' in title:
        return 'Data Analyst'
    else:
        return 'Other'

if 'Job Title' in df.columns:
    df['Job Title Group'] = df['Job Title'].apply(group_job_title)
    df.drop(columns=['Job Title'], inplace=True)
df
# Out:
#       Rating                        Company Name  Easy Apply  \
# 0        3.2           Vera Institute of Justice         0.0
# 1        3.8  Visiting Nurse Service of New York         0.0
# 2        3.4                         Squarespace         0.0
# 3        4.1                            Celerity         0.0
# 4        3.9                             FanDuel         0.0
# ...      ...                                 ...         ...
# 2248     2.5                       Avacend, Inc.         0.0
# 2249     2.9                   Arrow Electronics         0.0
# 2250     1.0                            Spiceorb         0.0
# 2251     3.1         Contingent Network Services         0.0
# 2252     3.4                          SCL Health         0.0
#
#      Salary Estimate Cleaned  Min Salary (K)  Max Salary (K)  Avg Salary (K)  \
# 0                      37-66            37.0            66.0            51.0
# 1                      37-66            37.0            66.0            51.0
# 2                      37-66            37.0            66.0            51.0
# 3                      37-66            37.0            66.0            51.0
# 4                      37-66            37.0            66.0            51.0
# ...                      ...             ...             ...             ...
# 2248                  78-104            78.0           104.0            91.0
# 2249                  78-104            78.0           104.0            91.0
# 2250                  78-104            78.0           104.0            91.0
# 2251                  78-104            78.0           104.0            91.0
# 2252                  78-104            78.0           104.0            91.0
#
#         Job City Job State       HQ City  ...  \
# 0       New York        NY      New York  ...
# 1       New York        NY      New York  ...
# 2       New York        NY      New York  ...
# 3       New York        NY        McLean  ...
# 4       New York        NY      New York  ...
# ...          ...       ...           ...  ...
# 2248      Denver        CO    Alpharetta  ...
# 2249  Centennial        CO    Centennial  ...
# 2250      Denver        CO            -1  ...
# 2251  Centennial        CO  West Chester  ...
# 2252  Broomfield        CO    Broomfield  ...
#
#      Job Title Simplified_Data Scientist  Job Title Simplified_Engineer  \
# 0                                  False                          False
# 1                                  False                          False
# 2                                  False                          False
# 3                                  False                          False
# 4                                  False                          False
# ...                                  ...                            ...
# 2248                               False                          False
# 2249                               False                          False
# 2250                               False                          False
# 2251                               False                          False
# 2252                               False                          False
#
#       Job Title Simplified_Intern  Job Title Simplified_Lead Analyst  \
# 0                           False                              False
# 1                           False                              False
# 2                           False                              False
# 3                           False                              False
# 4                           False                              False
# ...                           ...                                ...
# 2248                        False                              False
# 2249                        False                              False
# 2250                        False                              False
# 2251                        False                              False
# 2252                        False                              False
#
#       Job Title Simplified_Manager  Job Title Simplified_Senior Analyst  \
# 0                            False                                False
# 1                            False                                False
# 2                            False                                 True
# 3                            False                                False
# 4                            False                                False
# ...                            ...                                  ...
# 2248                         False                                False
# 2249                         False                                 True
# 2250                         False                                False
# 2251                         False                                False
# 2252                         False                                 True
#
#       Salary Range (K)  Average Salary (K)  Log Avg Salary  \
# 0                 29.0                51.5        3.941582
# 1                 29.0                51.5        3.941582
# 2                 29.0                51.5        3.941582
# 3                 29.0                51.5        3.941582
# 4                 29.0                51.5        3.941582
# ...                ...                 ...             ...
# 2248              26.0                91.0        4.510860
# 2249              26.0                91.0        4.510860
# 2250              26.0                91.0        4.510860
# 2251              26.0                91.0        4.510860
# 2252              26.0                91.0        4.510860
#
#              Job Title Group
# 0     Mid-level Data Analyst
# 1       Data Quality Analyst
# 2        Senior Data Analyst
# 3               Data Analyst
# 4          Reporting Analyst
# ...                      ...
# 2248  Mid-level Data Analyst
# 2249     Senior Data Analyst
# 2250        Business Analyst
# 2251  Mid-level Data Analyst
# 2252     Senior Data Analyst
#
# [2253 rows x 171 columns]

# %% [markdown]
# # 1. Which job roles, locations, and companies dominate the hiring space?

# %% [markdown]
# # Top 10 In-Demand Job Titles

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Setting of style
sns.set(style="whitegrid")


df['Job Title '] = df['Job Title Group'].apply(group_job_title)

# Data
top_jobs = df['Job Title Group'].value_counts().head(10)

#  figure and axis
plt.figure(figsize=(12, 6))
ax = sns.barplot(x=top_jobs.values, y=top_jobs.index, palette="crest")

# Title & Labels
plt.title(" 10 In-Demand Job Titles", fontsize=16, weight='bold', loc='left', pad=15)
plt.xlabel("Number of Listings", fontsize=12)
plt.ylabel("Job Title", fontsize=12)

#  count labels next to bars
for i, v in enumerate(top_jobs.values):
    ax.text(v + 1, i, str(v), color='black', va='center', fontweight='bold')

# Final result
sns.despine(left=True, bottom=True)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-14-c6543b7272f2>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=top_jobs.values, y=top_jobs.index, palette="crest")

# %% [markdown]
# # Top 10 Hiring Locations

# %%
top_locations = df['Job City'].value_counts().head(10)
top_locations.plot(kind='barh', figsize=(10,6), color='lightgreen')
plt.title("Top 10 Hiring Locations")
plt.xlabel("Number of Listings")
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# # Top 10 Companies Hiring

# %%
if 'Company Name' in df.columns:
	top_companies = df['Company Name'].value_counts().head(10)
	top_companies.plot(kind='barh', figsize=(10,6), color='salmon')
	plt.title("🏢 Top 10 Companies Hiring")
	plt.xlabel("Number of Listings")
	plt.gca().invert_yaxis()
	plt.show()
else:
	print("Column 'Company Name' not found in the DataFrame.")
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 127970 (\N{OFFICE BUILDING}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # 2. How do company rating and job location impact average salaries?

# %% [markdown]
# # company Rating vs Avg Salary

# %%
df['Rating'] = df['Rating'].replace(-1, 0)

rating_salary = df.groupby('Rating')['Avg Salary (K)'].mean().sort_index()
rating_salary.plot(kind='line', marker='o', color='purple')
plt.title(" Company Rating vs Avg Salary")
plt.xlabel("Rating")
plt.ylabel("Avg Salary (K)")
plt.grid(True)
plt.show()

# %% [markdown]
# # Top Paying Locations

# %%
location_salary = df.groupby('Job City')['Avg Salary (K)'].mean().sort_values(ascending=False).head(10)
location_salary.plot(kind='bar', figsize=(10,6), color='orange')
plt.title(" Top Paying Locations(City)")
plt.ylabel("Avg Salary (K)")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Data Processing  and Data Modellinig for salary prediction

# %%
# Define the clean_job_title function
def clean_job_title(title):
    title = str(title).lower()
    if 'senior' in title or 'sr' in title:
        return 'Senior Analyst'
    elif 'manager' in title:
        return 'Manager'
    elif 'intern' in title:
        return 'Intern'
    elif 'lead' in title:
        return 'Lead Analyst'
    elif 'data scientist' in title:
        return 'Data Scientist'
    elif 'engineer' in title:
        return 'Engineer'
    else:
        return 'Analyst'

# Defensive check for expected columns
if 'Job Title Group' in df.columns:
    df['Job Title Cleaned'] = df['Job Title Group'].apply(clean_job_title)
else:
    print(" Column 'Job Title' not found in dataframe!")

# Convert salary to numeric
for col in ['Min Salary (K)', 'Max Salary (K)']:
    if col in df.columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')
    else:
        print(f" Column '{col}' not found in dataframe!")

# Feature engineering
df['Salary Range (K)'] = df['Max Salary (K)'] - df['Min Salary (K)']
df['Avg Salary (K)'] = (df['Min Salary (K)'] + df['Max Salary (K)']) / 2
df['Log Avg Salary'] = df['Average Salary (K)'].apply(lambda x: np.log(x) if pd.notna(x) and x > 0 else np.nan)

# Now safely drop missing values
required_cols = ['Avg Salary (K)', 'Job Title Cleaned']
for col in required_cols:
    if col not in df.columns:
        raise KeyError(f"Column '{col}' is missing from dataframe.")

df.dropna(subset=required_cols, inplace=True)
df
# Out:
#       Rating                        Company Name  Easy Apply  \
# 0        3.2           Vera Institute of Justice         0.0
# 1        3.8  Visiting Nurse Service of New York         0.0
# 2        3.4                         Squarespace         0.0
# 3        4.1                            Celerity         0.0
# 4        3.9                             FanDuel         0.0
# ...      ...                                 ...         ...
# 2248     2.5                       Avacend, Inc.         0.0
# 2249     2.9                   Arrow Electronics         0.0
# 2250     1.0                            Spiceorb         0.0
# 2251     3.1         Contingent Network Services         0.0
# 2252     3.4                          SCL Health         0.0
#
#      Salary Estimate Cleaned  Min Salary (K)  Max Salary (K)  Avg Salary (K)  \
# 0                      37-66            37.0            66.0            51.5
# 1                      37-66            37.0            66.0            51.5
# 2                      37-66            37.0            66.0            51.5
# 3                      37-66            37.0            66.0            51.5
# 4                      37-66            37.0            66.0            51.5
# ...                      ...             ...             ...             ...
# 2248                  78-104            78.0           104.0            91.0
# 2249                  78-104            78.0           104.0            91.0
# 2250                  78-104            78.0           104.0            91.0
# 2251                  78-104            78.0           104.0            91.0
# 2252                  78-104            78.0           104.0            91.0
#
#         Job City Job State       HQ City  ... Job Title Simplified_Intern  \
# 0       New York        NY      New York  ...                       False
# 1       New York        NY      New York  ...                       False
# 2       New York        NY      New York  ...                       False
# 3       New York        NY        McLean  ...                       False
# 4       New York        NY      New York  ...                       False
# ...          ...       ...           ...  ...                         ...
# 2248      Denver        CO    Alpharetta  ...                       False
# 2249  Centennial        CO    Centennial  ...                       False
# 2250      Denver        CO            -1  ...                       False
# 2251  Centennial        CO  West Chester  ...                       False
# 2252  Broomfield        CO    Broomfield  ...                       False
#
#       Job Title Simplified_Lead Analyst  Job Title Simplified_Manager  \
# 0                                 False                         False
# 1                                 False                         False
# 2                                 False                         False
# 3                                 False                         False
# 4                                 False                         False
# ...                                 ...                           ...
# 2248                              False                         False
# 2249                              False                         False
# 2250                              False                         False
# 2251                              False                         False
# 2252                              False                         False
#
#       Job Title Simplified_Senior Analyst  Salary Range (K)  \
# 0                                   False              29.0
# 1                                   False              29.0
# 2                                    True              29.0
# 3                                   False              29.0
# 4                                   False              29.0
# ...                                   ...               ...
# 2248                                False              26.0
# 2249                                 True              26.0
# 2250                                False              26.0
# 2251                                False              26.0
# 2252                                 True              26.0
#
#       Average Salary (K)  Log Avg Salary         Job Title Group  \
# 0                   51.5        3.941582  Mid-level Data Analyst
# 1                   51.5        3.941582    Data Quality Analyst
# 2                   51.5        3.941582     Senior Data Analyst
# 3                   51.5        3.941582            Data Analyst
# 4                   51.5        3.941582       Reporting Analyst
# ...                  ...             ...                     ...
# 2248                91.0        4.510860  Mid-level Data Analyst
# 2249                91.0        4.510860     Senior Data Analyst
# 2250                91.0        4.510860        Business Analyst
# 2251                91.0        4.510860  Mid-level Data Analyst
# 2252                91.0        4.510860     Senior Data Analyst
#
#                   Job Title   Job Title Cleaned
# 0     Mid-level Data Analyst            Analyst
# 1       Data Quality Analyst            Analyst
# 2        Senior Data Analyst     Senior Analyst
# 3               Data Analyst            Analyst
# 4          Reporting Analyst            Analyst
# ...                      ...                ...
# 2248  Mid-level Data Analyst            Analyst
# 2249     Senior Data Analyst     Senior Analyst
# 2250        Business Analyst            Analyst
# 2251  Mid-level Data Analyst            Analyst
# 2252     Senior Data Analyst     Senior Analyst
#
# [2252 rows x 173 columns]

# %%
pd.set_option('display.max_columns', None)

# Now print all columns
print(df.columns)
# Out:
# Index(['Rating', 'Company Name', 'Easy Apply', 'Salary Estimate Cleaned',
#        'Min Salary (K)', 'Max Salary (K)', 'Avg Salary (K)', 'Job City',
#        'Job State', 'HQ City',
#        ...
#        'Job Title Simplified_Intern', 'Job Title Simplified_Lead Analyst',
#        'Job Title Simplified_Manager', 'Job Title Simplified_Senior Analyst',
#        'Salary Range (K)', 'Average Salary (K)', 'Log Avg Salary',
#        'Job Title Group', 'Job Title ', 'Job Title Cleaned'],
#       dtype='object', length=173)

# %%
import re

def clean_job_title(title):
    title = title.lower()
    title = re.sub(r'[^a-zA-Z\s]', '', title)  # remove punctuation
    title = re.sub(r'\b(remote|full time|part time|contract|internship|temporary)\b', '', title)
    title = title.strip()
    return title

df['Job Title Normalized'] = df['Job Title Cleaned'].apply(clean_job_title)

def job_level(title):
    if 'intern' in title:
        return 'Entry Level'
    elif 'junior' in title or 'analyst' in title:
        return 'Entry Level'
    elif 'senior' in title or 'lead' in title:
        return 'Mid Level'
    elif 'manager' in title or 'head' in title or 'supervisor' in title:
        return 'Leadership'
    elif 'director' in title or 'vp' in title or 'chief' in title:
        return 'Executive'
    elif 'engineer' in title or 'scientist' in title or 'developer' in title:
        return 'Tech Specialist'
    else:
        return 'Other'

df['Job Level'] = df['Job Title Normalized'].apply(job_level)

# One-hot encoding
df = pd.get_dummies(df, columns=['Job Level'], drop_first=True)
df.drop(['Job Title Cleaned', 'Job Title Normalized','Avg Salary (K)'], axis=1, inplace=True)
df
# Out:
#       Rating                        Company Name  Easy Apply  \
# 0        3.2           Vera Institute of Justice         0.0
# 1        3.8  Visiting Nurse Service of New York         0.0
# 2        3.4                         Squarespace         0.0
# 3        4.1                            Celerity         0.0
# 4        3.9                             FanDuel         0.0
# ...      ...                                 ...         ...
# 2248     2.5                       Avacend, Inc.         0.0
# 2249     2.9                   Arrow Electronics         0.0
# 2250     1.0                            Spiceorb         0.0
# 2251     3.1         Contingent Network Services         0.0
# 2252     3.4                          SCL Health         0.0
#
#      Salary Estimate Cleaned  Min Salary (K)  Max Salary (K)    Job City  \
# 0                      37-66            37.0            66.0    New York
# 1                      37-66            37.0            66.0    New York
# 2                      37-66            37.0            66.0    New York
# 3                      37-66            37.0            66.0    New York
# 4                      37-66            37.0            66.0    New York
# ...                      ...             ...             ...         ...
# 2248                  78-104            78.0           104.0      Denver
# 2249                  78-104            78.0           104.0  Centennial
# 2250                  78-104            78.0           104.0      Denver
# 2251                  78-104            78.0           104.0  Centennial
# 2252                  78-104            78.0           104.0  Broomfield
#
#      Job State       HQ City HQ State  Skill_Python  Skill_Excel  Skill_SQL  \
# 0           NY      New York       NY          True        False       True
# 1           NY      New York       NY         False         True       True
# 2           NY      New York       NY          True         True       True
# 3           NY        McLean       VA         False        False       True
# 4           NY      New York       NY          True         True       True
# ...        ...           ...      ...           ...          ...        ...
# 2248        CO    Alpharetta       GA         False        False      False
# 2249        CO    Centennial       CO         False        False       True
# 2250        CO            -1     None         False         True       True
# 2251        CO  West Chester       OH          True        False       True
# 2252        CO    Broomfield       CO         False         True      False
#
#       Skill_R  Skill_Tableau  Skill_Power BI  Skill_Machine Learning  \
# 0        True          False           False                   False
# 1        True          False           False                   False
# 2        True           True           False                   False
# 3        True           True           False                   False
# 4        True          False           False                   False
# ...       ...            ...             ...                     ...
# 2248     True          False           False                   False
# 2249     True           True           False                   False
# 2250     True          False           False                   False
# 2251     True          False           False                    True
# 2252     True           True           False                   False
#
#       Company_Encoded  Size_10000+ employees  Size_1001 to 5000 employees  \
# 0                1399                  False                        False
# 1                1420                   True                        False
# 2                1181                  False                         True
# 3                 244                  False                        False
# 4                 469                  False                        False
# ...               ...                    ...                          ...
# 2248              135                  False                        False
# 2249              114                   True                        False
# 2250             1175                  False                        False
# 2251              316                  False                        False
# 2252             1092                   True                        False
#
#       Size_201 to 500 employees  Size_5001 to 10000 employees  \
# 0                          True                         False
# 1                         False                         False
# 2                         False                         False
# 3                          True                         False
# 4                         False                         False
# ...                         ...                           ...
# 2248                      False                         False
# 2249                      False                         False
# 2250                      False                         False
# 2251                       True                         False
# 2252                      False                         False
#
#       Size_501 to 1000 employees  Size_51 to 200 employees  Size_Unknown  \
# 0                          False                     False         False
# 1                          False                     False         False
# 2                          False                     False         False
# 3                          False                     False         False
# 4                           True                     False         False
# ...                          ...                       ...           ...
# 2248                       False                      True         False
# 2249                       False                     False         False
# 2250                       False                     False         False
# 2251                       False                     False         False
# 2252                       False                     False         False
#
#       Revenue_$1 to $5 million (USD)  Revenue_$10 to $25 million (USD)  \
# 0                              False                             False
# 1                              False                             False
# 2                              False                             False
# 3                              False                             False
# 4                              False                             False
# ...                              ...                               ...
# 2248                           False                             False
# 2249                           False                             False
# 2250                           False                             False
# 2251                           False                             False
# 2252                           False                             False
#
#       Revenue_$10+ billion (USD)  Revenue_$100 to $500 million (USD)  \
# 0                          False                                True
# 1                          False                               False
# 2                          False                               False
# 3                          False                               False
# 4                          False                                True
# ...                          ...                                 ...
# 2248                       False                               False
# 2249                        True                               False
# 2250                       False                               False
# 2251                       False                               False
# 2252                       False                               False
#
#       Revenue_$2 to $5 billion (USD)  Revenue_$25 to $50 million (USD)  \
# 0                              False                             False
# 1                               True                             False
# 2                              False                             False
# 3                              False                             False
# 4                              False                             False
# ...                              ...                               ...
# 2248                           False                             False
# 2249                           False                             False
# 2250                           False                             False
# 2251                           False                              True
# 2252                            True                             False
#
#       Revenue_$5 to $10 billion (USD)  Revenue_$5 to $10 million (USD)  \
# 0                               False                            False
# 1                               False                            False
# 2                               False                            False
# 3                               False                            False
# 4                               False                            False
# ...                               ...                              ...
# 2248                            False                            False
# 2249                            False                            False
# 2250                            False                            False
# 2251                            False                            False
# 2252                            False                            False
#
#       Revenue_$50 to $100 million (USD)  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                  True
# 4                                 False
# ...                                 ...
# 2248                              False
# 2249                              False
# 2250                              False
# 2251                              False
# 2252                              False
#
#       Revenue_$500 million to $1 billion (USD)  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 2248                                     False
# 2249                                     False
# 2250                                     False
# 2251                                     False
# 2252                                     False
#
#       Revenue_Less than $1 million (USD)  Revenue_Unknown / Non-Applicable  \
# 0                                  False                             False
# 1                                  False                             False
# 2                                  False                              True
# 3                                  False                             False
# 4                                  False                             False
# ...                                  ...                               ...
# 2248                               False                              True
# 2249                               False                             False
# 2250                               False                             False
# 2251                               False                             False
# 2252                               False                             False
#
#       Type of ownership_Company - Private  Type of ownership_Company - Public  \
# 0                                   False                               False
# 1                                   False                               False
# 2                                    True                               False
# 3                                   False                               False
# 4                                    True                               False
# ...                                   ...                                 ...
# 2248                                 True                               False
# 2249                                False                                True
# 2250                                False                               False
# 2251                                 True                               False
# 2252                                False                               False
#
#       Type of ownership_Contract  Type of ownership_Franchise  \
# 0                          False                        False
# 1                          False                        False
# 2                          False                        False
# 3                          False                        False
# 4                          False                        False
# ...                          ...                          ...
# 2248                       False                        False
# 2249                       False                        False
# 2250                       False                        False
# 2251                       False                        False
# 2252                       False                        False
#
#       Type of ownership_Government  Type of ownership_Hospital  \
# 0                            False                       False
# 1                            False                       False
# 2                            False                       False
# 3                            False                       False
# 4                            False                       False
# ...                            ...                         ...
# 2248                         False                       False
# 2249                         False                       False
# 2250                         False                       False
# 2251                         False                       False
# 2252                         False                       False
#
#       Type of ownership_Nonprofit Organization  \
# 0                                         True
# 1                                         True
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 2248                                     False
# 2249                                     False
# 2250                                     False
# 2251                                     False
# 2252                                      True
#
#       Type of ownership_Other Organization  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ...                                    ...
# 2248                                 False
# 2249                                 False
# 2250                                 False
# 2251                                 False
# 2252                                 False
#
#       Type of ownership_Private Practice / Firm  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 2248                                      False
# 2249                                      False
# 2250                                      False
# 2251                                      False
# 2252                                      False
#
#       Type of ownership_School / School District  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 2248                                       False
# 2249                                       False
# 2250                                       False
# 2251                                       False
# 2252                                       False
#
#       Type of ownership_Self-employed  \
# 0                               False
# 1                               False
# 2                               False
# 3                               False
# 4                               False
# ...                               ...
# 2248                            False
# 2249                            False
# 2250                            False
# 2251                            False
# 2252                            False
#
#       Type of ownership_Subsidiary or Business Segment  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                 True
# 4                                                False
# ...                                                ...
# 2248                                             False
# 2249                                             False
# 2250                                             False
# 2251                                             False
# 2252                                             False
#
#       Type of ownership_Unknown  Industry_Advertising & Marketing  \
# 0                         False                             False
# 1                         False                             False
# 2                         False                             False
# 3                         False                             False
# 4                         False                             False
# ...                         ...                               ...
# 2248                      False                             False
# 2249                      False                             False
# 2250                      False                             False
# 2251                      False                             False
# 2252                      False                             False
#
#       Industry_Aerospace & Defense  \
# 0                            False
# 1                            False
# 2                            False
# 3                            False
# 4                            False
# ...                            ...
# 2248                         False
# 2249                         False
# 2250                         False
# 2251                         False
# 2252                         False
#
#       Industry_Architectural & Engineering Services  Industry_Audiovisual  \
# 0                                             False                 False
# 1                                             False                 False
# 2                                             False                 False
# 3                                             False                 False
# 4                                             False                 False
# ...                                             ...                   ...
# 2248                                          False                 False
# 2249                                          False                 False
# 2250                                          False                 False
# 2251                                          False                 False
# 2252                                          False                 False
#
#       Industry_Automotive Parts & Accessories Stores  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# ...                                              ...
# 2248                                           False
# 2249                                           False
# 2250                                           False
# 2251                                           False
# 2252                                           False
#
#       Industry_Banks & Credit Unions  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
# ...                              ...
# 2248                           False
# 2249                           False
# 2250                           False
# 2251                           False
# 2252                           False
#
#       Industry_Beauty & Personal Accessories Stores  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
# ...                                             ...
# 2248                                          False
# 2249                                          False
# 2250                                          False
# 2251                                          False
# 2252                                          False
#
#       Industry_Biotech & Pharmaceuticals  Industry_Brokerage Services  \
# 0                                  False                        False
# 1                                  False                        False
# 2                                  False                        False
# 3                                  False                        False
# 4                                  False                        False
# ...                                  ...                          ...
# 2248                               False                        False
# 2249                               False                        False
# 2250                               False                        False
# 2251                               False                        False
# 2252                               False                        False
#
#       Industry_Building & Personnel Services  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ...                                      ...
# 2248                                   False
# 2249                                   False
# 2250                                   False
# 2251                                   False
# 2252                                   False
#
#       Industry_Cable, Internet & Telephone Providers  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# ...                                              ...
# 2248                                           False
# 2249                                           False
# 2250                                           False
# 2251                                           False
# 2252                                           False
#
#       Industry_Casual Restaurants  \
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
# ...                           ...
# 2248                        False
# 2249                        False
# 2250                        False
# 2251                        False
# 2252                        False
#
#       Industry_Catering & Food Service Contractors  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 2248                                         False
# 2249                                         False
# 2250                                         False
# 2251                                         False
# 2252                                         False
#
#       Industry_Chemical Manufacturing  Industry_Colleges & Universities  \
# 0                               False                             False
# 1                               False                             False
# 2                               False                             False
# 3                               False                             False
# 4                               False                             False
# ...                               ...                               ...
# 2248                            False                             False
# 2249                            False                             False
# 2250                            False                             False
# 2251                            False                             False
# 2252                            False                             False
#
#       Industry_Commercial Equipment Repair & Maintenance  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2248                                              False
# 2249                                              False
# 2250                                              False
# 2251                                              False
# 2252                                              False
#
#       Industry_Computer Hardware & Software  Industry_Construction  \
# 0                                     False                  False
# 1                                     False                  False
# 2                                     False                  False
# 3                                     False                  False
# 4                                     False                  False
# ...                                     ...                    ...
# 2248                                  False                  False
# 2249                                  False                  False
# 2250                                  False                  False
# 2251                                  False                  False
# 2252                                  False                  False
#
#       Industry_Consulting  Industry_Consumer Electronics & Appliances Stores  \
# 0                   False                                              False
# 1                   False                                              False
# 2                   False                                              False
# 3                   False                                              False
# 4                   False                                              False
# ...                   ...                                                ...
# 2248                False                                              False
# 2249                False                                              False
# 2250                False                                              False
# 2251                False                                              False
# 2252                False                                              False
#
#       Industry_Consumer Product Rental  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# ...                                ...
# 2248                             False
# 2249                             False
# 2250                             False
# 2251                             False
# 2252                             False
#
#       Industry_Consumer Products Manufacturing  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 2248                                     False
# 2249                                     False
# 2250                                     False
# 2251                                     False
# 2252                                     False
#
#       Industry_Convenience Stores & Truck Stops  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 2248                                      False
# 2249                                      False
# 2250                                      False
# 2251                                      False
# 2252                                      False
#
#       Industry_Department, Clothing, & Shoe Stores  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 2248                                         False
# 2249                                         False
# 2250                                         False
# 2251                                         False
# 2252                                         False
#
#       Industry_Drug & Health Stores  Industry_Education Training Services  \
# 0                             False                                 False
# 1                             False                                 False
# 2                             False                                 False
# 3                             False                                 False
# 4                             False                                 False
# ...                             ...                                   ...
# 2248                          False                                 False
# 2249                          False                                 False
# 2250                          False                                 False
# 2251                          False                                 False
# 2252                          False                                 False
#
#       Industry_Electrical & Electronic Manufacturing  Industry_Energy  \
# 0                                              False            False
# 1                                              False            False
# 2                                              False            False
# 3                                              False            False
# 4                                              False            False
# ...                                              ...              ...
# 2248                                           False            False
# 2249                                           False            False
# 2250                                           False            False
# 2251                                           False            False
# 2252                                           False            False
#
#       Industry_Enterprise Software & Network Solutions  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ...                                                ...
# 2248                                             False
# 2249                                             False
# 2250                                             False
# 2251                                              True
# 2252                                             False
#
#       Industry_Express Delivery Services  Industry_Federal Agencies  \
# 0                                  False                      False
# 1                                  False                      False
# 2                                  False                      False
# 3                                  False                      False
# 4                                  False                      False
# ...                                  ...                        ...
# 2248                               False                      False
# 2249                               False                      False
# 2250                               False                      False
# 2251                               False                      False
# 2252                               False                      False
#
#       Industry_Financial Analytics & Research  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ...                                       ...
# 2248                                    False
# 2249                                    False
# 2250                                    False
# 2251                                    False
# 2252                                    False
#
#       Industry_Financial Transaction Processing  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 2248                                      False
# 2249                                      False
# 2250                                      False
# 2251                                      False
# 2252                                      False
#
#       Industry_Food & Beverage Manufacturing  Industry_Food & Beverage Stores  \
# 0                                      False                            False
# 1                                      False                            False
# 2                                      False                            False
# 3                                      False                            False
# 4                                      False                            False
# ...                                      ...                              ...
# 2248                                   False                            False
# 2249                                   False                            False
# 2250                                   False                            False
# 2251                                   False                            False
# 2252                                   False                            False
#
#       Industry_Gambling  Industry_Gas Stations  \
# 0                 False                  False
# 1                 False                  False
# 2                 False                  False
# 3                 False                  False
# 4                 False                  False
# ...                 ...                    ...
# 2248              False                  False
# 2249              False                  False
# 2250              False                  False
# 2251              False                  False
# 2252              False                  False
#
#       Industry_General Merchandise & Superstores  \
# 0                                          False
# 1                                          False
# 2                                          False
# 3                                          False
# 4                                          False
# ...                                          ...
# 2248                                       False
# 2249                                       False
# 2250                                       False
# 2251                                       False
# 2252                                       False
#
#       Industry_General Repair & Maintenance  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# ...                                     ...
# 2248                                  False
# 2249                                  False
# 2250                                  False
# 2251                                  False
# 2252                                  False
#
#       Industry_Grocery Stores & Supermarkets  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ...                                      ...
# 2248                                   False
# 2249                                   False
# 2250                                   False
# 2251                                   False
# 2252                                   False
#
#       Industry_Health Care Products Manufacturing  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
# ...                                           ...
# 2248                                        False
# 2249                                        False
# 2250                                        False
# 2251                                        False
# 2252                                        False
#
#       Industry_Health Care Services & Hospitals  \
# 0                                         False
# 1                                          True
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 2248                                      False
# 2249                                      False
# 2250                                      False
# 2251                                      False
# 2252                                       True
#
#       Industry_Health Fundraising Organizations  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ...                                         ...
# 2248                                      False
# 2249                                      False
# 2250                                      False
# 2251                                      False
# 2252                                      False
#
#       Industry_Health, Beauty, & Fitness  \
# 0                                  False
# 1                                  False
# 2                                  False
# 3                                  False
# 4                                  False
# ...                                  ...
# 2248                               False
# 2249                               False
# 2250                               False
# 2251                               False
# 2252                               False
#
#       Industry_Home Centers & Hardware Stores  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ...                                       ...
# 2248                                    False
# 2249                                    False
# 2250                                    False
# 2251                                    False
# 2252                                    False
#
#       Industry_Hotels, Motels, & Resorts  Industry_IT Services  \
# 0                                  False                 False
# 1                                  False                 False
# 2                                  False                 False
# 3                                  False                  True
# 4                                  False                 False
# ...                                  ...                   ...
# 2248                               False                 False
# 2249                               False                 False
# 2250                               False                 False
# 2251                               False                 False
# 2252                               False                 False
#
#       Industry_Industrial Manufacturing  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ...                                 ...
# 2248                              False
# 2249                              False
# 2250                              False
# 2251                              False
# 2252                              False
#
#       Industry_Insurance Agencies & Brokerages  Industry_Insurance Carriers  \
# 0                                        False                        False
# 1                                        False                        False
# 2                                        False                        False
# 3                                        False                        False
# 4                                        False                        False
# ...                                        ...                          ...
# 2248                                     False                        False
# 2249                                     False                        False
# 2250                                     False                        False
# 2251                                     False                        False
# 2252                                     False                        False
#
#       Industry_Internet  Industry_Investment Banking & Asset Management  \
# 0                 False                                           False
# 1                 False                                           False
# 2                  True                                           False
# 3                 False                                           False
# 4                 False                                           False
# ...                 ...                                             ...
# 2248              False                                           False
# 2249              False                                           False
# 2250              False                                           False
# 2251              False                                           False
# 2252              False                                           False
#
#       Industry_K-12 Education  Industry_Legal  Industry_Lending  \
# 0                       False           False             False
# 1                       False           False             False
# 2                       False           False             False
# 3                       False           False             False
# 4                       False           False             False
# ...                       ...             ...               ...
# 2248                    False           False             False
# 2249                    False           False             False
# 2250                    False           False             False
# 2251                    False           False             False
# 2252                    False           False             False
#
#       Industry_Logistics & Supply Chain  Industry_Membership Organizations  \
# 0                                 False                              False
# 1                                 False                              False
# 2                                 False                              False
# 3                                 False                              False
# 4                                 False                              False
# ...                                 ...                                ...
# 2248                              False                              False
# 2249                              False                              False
# 2250                              False                              False
# 2251                              False                              False
# 2252                              False                              False
#
#       Industry_Metals Brokers  Industry_Miscellaneous Manufacturing  \
# 0                       False                                 False
# 1                       False                                 False
# 2                       False                                 False
# 3                       False                                 False
# 4                       False                                 False
# ...                       ...                                   ...
# 2248                    False                                 False
# 2249                    False                                 False
# 2250                    False                                 False
# 2251                    False                                 False
# 2252                    False                                 False
#
#       Industry_Motion Picture Production & Distribution  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 2248                                              False
# ...
# ...                                               ...
# 2248                                            False
# 2249                                            False
# 2250                                            False
# 2251                                            False
# 2252                                            False
#
#       Industry_Transportation Management  Industry_Truck Rental & Leasing  \
# 0                                  False                            False
# 1                                  False                            False
# 2                                  False                            False
# 3                                  False                            False
# 4                                  False                            False
# ...                                  ...                              ...
# 2248                               False                            False
# 2249                               False                            False
# 2250                               False                            False
# 2251                               False                            False
# 2252                               False                            False
#
#       Industry_Trucking  Industry_Utilities  Industry_Vehicle Dealers  \
# 0                 False               False                     False
# 1                 False               False                     False
# 2                 False               False                     False
# 3                 False               False                     False
# 4                 False               False                     False
# ...                 ...                 ...                       ...
# 2248              False               False                     False
# 2249              False               False                     False
# 2250              False               False                     False
# 2251              False               False                     False
# 2252              False               False                     False
#
#       Industry_Venture Capital & Private Equity  Industry_Video Games  \
# 0                                         False                 False
# 1                                         False                 False
# 2                                         False                 False
# 3                                         False                 False
# 4                                         False                 False
# ...                                         ...                   ...
# 2248                                      False                 False
# 2249                                      False                 False
# 2250                                      False                 False
# 2251                                      False                 False
# 2252                                      False                 False
#
#       Industry_Wholesale  Sector_Aerospace & Defense  \
# 0                  False                       False
# 1                  False                       False
# 2                  False                       False
# 3                  False                       False
# 4                  False                       False
# ...                  ...                         ...
# 2248               False                       False
# 2249                True                       False
# 2250               False                       False
# 2251               False                       False
# 2252               False                       False
#
#       Sector_Arts, Entertainment & Recreation  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                        True
# ...                                       ...
# 2248                                    False
# 2249                                    False
# 2250                                    False
# 2251                                    False
# 2252                                    False
#
#       Sector_Biotech & Pharmaceuticals  Sector_Business Services  \
# 0                                False                     False
# 1                                False                     False
# 2                                False                     False
# 3                                False                     False
# 4                                False                     False
# ...                                ...                       ...
# 2248                             False                      True
# 2249                             False                      True
# 2250                             False                     False
# 2251                             False                     False
# 2252                             False                     False
#
#       Sector_Construction, Repair & Maintenance  Sector_Consumer Services  \
# 0                                         False                     False
# 1                                         False                     False
# 2                                         False                     False
# 3                                         False                     False
# 4                                         False                     False
# ...                                         ...                       ...
# 2248                                      False                     False
# 2249                                      False                     False
# 2250                                      False                     False
# 2251                                      False                     False
# 2252                                      False                     False
#
#       Sector_Education  Sector_Finance  Sector_Government  Sector_Health Care  \
# 0                False           False              False               False
# 1                False           False              False                True
# 2                False           False              False               False
# 3                False           False              False               False
# 4                False           False              False               False
# ...                ...             ...                ...                 ...
# 2248             False           False              False               False
# 2249             False           False              False               False
# 2250             False           False              False               False
# 2251             False           False              False               False
# 2252             False           False              False                True
#
#       Sector_Information Technology  Sector_Insurance  Sector_Manufacturing  \
# 0                             False             False                 False
# 1                             False             False                 False
# 2                              True             False                 False
# 3                              True             False                 False
# 4                             False             False                 False
# ...                             ...               ...                   ...
# 2248                          False             False                 False
# 2249                          False             False                 False
# 2250                          False             False                 False
# 2251                           True             False                 False
# 2252                          False             False                 False
#
#       Sector_Media  Sector_Mining & Metals  Sector_Non-Profit  \
# 0            False                   False               True
# 1            False                   False              False
# 2            False                   False              False
# 3            False                   False              False
# 4            False                   False              False
# ...            ...                     ...                ...
# 2248         False                   False              False
# 2249         False                   False              False
# 2250         False                   False              False
# 2251         False                   False              False
# 2252         False                   False              False
#
#       Sector_Oil, Gas, Energy & Utilities  Sector_Real Estate  \
# 0                                   False               False
# 1                                   False               False
# 2                                   False               False
# 3                                   False               False
# 4                                   False               False
# ...                                   ...                 ...
# 2248                                False               False
# 2249                                False               False
# 2250                                False               False
# 2251                                False               False
# 2252                                False               False
#
#       Sector_Restaurants, Bars & Food Services  Sector_Retail  \
# 0                                        False          False
# 1                                        False          False
# 2                                        False          False
# 3                                        False          False
# 4                                        False          False
# ...                                        ...            ...
# 2248                                     False          False
# 2249                                     False          False
# 2250                                     False          False
# 2251                                     False          False
# 2252                                     False          False
#
#       Sector_Telecommunications  Sector_Transportation & Logistics  \
# 0                         False                              False
# 1                         False                              False
# 2                         False                              False
# 3                         False                              False
# 4                         False                              False
# ...                         ...                                ...
# 2248                      False                              False
# 2249                      False                              False
# 2250                      False                              False
# 2251                      False                              False
# 2252                      False                              False
#
#       Sector_Travel & Tourism  Job Title Simplified_Data Scientist  \
# 0                       False                                False
# 1                       False                                False
# 2                       False                                False
# 3                       False                                False
# 4                       False                                False
# ...                       ...                                  ...
# 2248                    False                                False
# 2249                    False                                False
# 2250                    False                                False
# 2251                    False                                False
# 2252                    False                                False
#
#       Job Title Simplified_Engineer  Job Title Simplified_Intern  \
# 0                             False                        False
# 1                             False                        False
# 2                             False                        False
# 3                             False                        False
# 4                             False                        False
# ...                             ...                          ...
# 2248                          False                        False
# 2249                          False                        False
# 2250                          False                        False
# 2251                          False                        False
# 2252                          False                        False
#
#       Job Title Simplified_Lead Analyst  Job Title Simplified_Manager  \
# 0                                 False                         False
# 1                                 False                         False
# 2                                 False                         False
# 3                                 False                         False
# 4                                 False                         False
# ...                                 ...                           ...
# 2248                              False                         False
# 2249                              False                         False
# 2250                              False                         False
# 2251                              False                         False
# 2252                              False                         False
#
#       Job Title Simplified_Senior Analyst  Salary Range (K)  \
# 0                                   False              29.0
# 1                                   False              29.0
# 2                                    True              29.0
# 3                                   False              29.0
# 4                                   False              29.0
# ...                                   ...               ...
# 2248                                False              26.0
# 2249                                 True              26.0
# 2250                                False              26.0
# 2251                                False              26.0
# 2252                                 True              26.0
#
#       Average Salary (K)  Log Avg Salary         Job Title Group  \
# 0                   51.5        3.941582  Mid-level Data Analyst
# 1                   51.5        3.941582    Data Quality Analyst
# 2                   51.5        3.941582     Senior Data Analyst
# 3                   51.5        3.941582            Data Analyst
# 4                   51.5        3.941582       Reporting Analyst
# ...                  ...             ...                     ...
# 2248                91.0        4.510860  Mid-level Data Analyst
# 2249                91.0        4.510860     Senior Data Analyst
# 2250                91.0        4.510860        Business Analyst
# 2251                91.0        4.510860  Mid-level Data Analyst
# 2252                91.0        4.510860     Senior Data Analyst
#
#                   Job Title   Job Level_Tech Specialist
# 0     Mid-level Data Analyst                      False
# 1       Data Quality Analyst                      False
# 2        Senior Data Analyst                      False
# 3               Data Analyst                      False
# 4          Reporting Analyst                      False
# ...                      ...                        ...
# 2248  Mid-level Data Analyst                      False
# 2249     Senior Data Analyst                      False
# 2250        Business Analyst                      False
# 2251  Mid-level Data Analyst                      False
# 2252     Senior Data Analyst                      False
#
# [2252 rows x 172 columns]

# %%
print(df.columns)
# Out:
# Index(['Rating', 'Company Name', 'Easy Apply', 'Salary Estimate Cleaned',
#        'Min Salary (K)', 'Max Salary (K)', 'Job City', 'Job State', 'HQ City',
#        'HQ State',
#        ...
#        'Job Title Simplified_Intern', 'Job Title Simplified_Lead Analyst',
#        'Job Title Simplified_Manager', 'Job Title Simplified_Senior Analyst',
#        'Salary Range (K)', 'Average Salary (K)', 'Log Avg Salary',
#        'Job Title Group', 'Job Title ', 'Job Level_Tech Specialist'],
#       dtype='object', length=172)

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns
pd=df.to_csv("/content/drive/MyDrive/sp_19_app/halfcleaned_dataset.csv")
